# %%
import numpy as np
import IPython
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# %%
rate_g, arr_g = read("../data/piano-g.wav")
rate_f, arr_f = read("../data/piano-f.wav")
rate_a, arr_a = read("../data/piano-a.wav")

IPython.display.display(IPython.display.Audio(arr_g[:, 0], rate=rate))
IPython.display.display(IPython.display.Audio(arr_g[:, 1], rate=rate))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(arr_g[:, 0])
plt.show()

plt.plot(arr_g[:, 1])
plt.show()

# %%
g_fft = np.fft.fft(arr_g[:,0])
plt.plot(g_fft)
plt.show()

f_fft = np.fft.fft(arr_f[:,0])
plt.plot(f_fft)
plt.show()

a_fft = np.fft.fft(arr_a[:,0])
plt.plot(a_fft)
plt.show()
# Out:
# /Users/jiajunxu/Desktop/ece445/test/lib/python3.5/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Exception ignored in: <bound method Wave_write.__del__ of <wave.Wave_write object at 0x11398bcf8>>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/wave.py", line 316, in __del__
#     self.close()
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/wave.py", line 434, in close
#     self._ensure_header_written(0)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/wave.py", line 457, in _ensure_header_written
#     self._write_header(datasize)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/wave.py", line 474, in _write_header
#     self._sampwidth * 8, b'data'))
# struct.error: ushort format requires 0 <= number <= (32767 * 2 + 1)
